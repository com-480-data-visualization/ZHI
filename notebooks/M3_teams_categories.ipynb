# %%
# Useful imports
import pandas as pd
import scipy.stats as stats
import numpy as np

# %% [markdown]
# # Setup

# %%
# Load the players data
male_players_df = pd.read_csv('../data/male_players.csv', usecols=['player_id', 'fifa_version', 'fifa_update', 'short_name', 'overall', 'age', 'club_team_id', 'player_face_url'])

# %%
# Load the teams data
male_teams_df = pd.read_csv('../data/male_teams.csv', usecols=['team_id', 'team_name', 'fifa_version', 'fifa_update'])

# %%
display(male_players_df.head())
display(male_teams_df.head())

print("Male players length: ", len(male_players_df))
print("Male teams length:", len(male_teams_df))
# Out:
#    player_id  fifa_version  fifa_update      short_name  overall  age  \
# 0     158023            23            9        L. Messi       91   35
# 1     165153            23            9      K. Benzema       91   34
# 2     188545            23            9  R. Lewandowski       91   33
# 3     192985            23            9    K. De Bruyne       91   31
# 4     231747            23            9       K. Mbappé       91   23
#
#    club_team_id                                    player_face_url
# 0          73.0  https://cdn.sofifa.net/players/158/023/23_120.png
# 1         243.0  https://cdn.sofifa.net/players/165/153/23_120.png
# 2         241.0  https://cdn.sofifa.net/players/188/545/23_120.png
# 3          10.0  https://cdn.sofifa.net/players/192/985/23_120.png
# 4          73.0  https://cdn.sofifa.net/players/231/747/23_120.png
#    team_id  fifa_version  fifa_update            team_name
# 0       10            23            9      Manchester City
# 1       73            23            9  Paris Saint Germain
# 2      243            23            9          Real Madrid
# 3     1337            23            9              Germany
# 4        5            23            9              Chelsea
# Male players length:  10003590
# Male teams length: 385055

# %%
# Sanitize the data
male_players_df.sort_values(by=['fifa_version','fifa_update'], ascending=False, inplace=True)
male_players_df.drop_duplicates(subset=['player_id', 'fifa_version'], inplace=True, keep='first')

male_teams_df.sort_values(by=['fifa_version','fifa_update'], ascending=False, inplace=True)
male_teams_df.drop_duplicates(subset=['team_id', 'fifa_version'], inplace=True, keep='first')

# %%
# Merge the dataframes
merged_df = pd.merge(male_players_df, male_teams_df, left_on=['club_team_id', 'fifa_version'], right_on=['team_id', 'fifa_version'])

# Keep only the relevant columns
merged_df = merged_df.loc[:, ["player_id", "fifa_version", "short_name", "overall", "age", "team_id", "team_name", "player_face_url"]]

# Show the merged dataframe
display(merged_df.head())
print("Merged dataframe length: ", len(merged_df))
# Out:
#    player_id  fifa_version  short_name  overall  age  team_id  \
# 0     158023            23    L. Messi       91   35       73
# 1     231747            23   K. Mbappé       91   23       73
# 2     190871            23   Neymar Jr       89   30       73
# 3     193041            23    K. Navas       88   35       73
# 4     207865            23  Marquinhos       88   28       73
#
#              team_name                                    player_face_url
# 0  Paris Saint Germain  https://cdn.sofifa.net/players/158/023/23_120.png
# 1  Paris Saint Germain  https://cdn.sofifa.net/players/231/747/23_120.png
# 2  Paris Saint Germain  https://cdn.sofifa.net/players/190/871/23_120.png
# 3  Paris Saint Germain  https://cdn.sofifa.net/players/193/041/23_120.png
# 4  Paris Saint Germain  https://cdn.sofifa.net/players/207/865/23_120.png
# Merged dataframe length:  193801

# %% [markdown]
# # Naive approach

# %%
# Identify rising stars, peak players, and falling stars
merged_df['rising_star'] = (merged_df['age'] <= 23) & (merged_df['overall'] >= merged_df[merged_df['age'] <= 23]['overall'].quantile(0.90))
merged_df['peak_player'] = (merged_df['age'].between(24, 29)) & (merged_df['overall'] >= merged_df[merged_df['age'].between(24, 29)]['overall'].quantile(0.90))
merged_df['falling_star'] = (merged_df['age'] >= 30) & (merged_df['overall'] < merged_df[merged_df['age'] >= 30]['overall'].quantile(0.90))

# Calculate club rankings based on the count of each type of player
club_rising_stars_rank = merged_df.groupby('team_name')['rising_star'].mean().sort_values(ascending=False)
club_peak_players_rank = merged_df.groupby('team_name')['peak_player'].mean().sort_values(ascending=False)
club_falling_stars_rank = merged_df.groupby('team_name')['falling_star'].mean().sort_values(ascending=False)

# %%
# Show the rankings
display(club_rising_stars_rank.head(10))
display(club_peak_players_rank.head(10))
display(club_falling_stars_rank.head(10))
# Out:
# team_name
# Salzburg               0.460177
# Nice                   0.434783
# Ajax                   0.390572
# Avaí                   0.350000
# PSV                    0.341463
# Bayer 04 Leverkusen    0.339921
# Lille                  0.338983
# Milan                  0.338843
# CSKA Moskva            0.333333
# Fortaleza              0.329545
# Name: rising_star, dtype: float64
# team_name
# Napoli                     0.449612
# Sevilla FC                 0.421687
# Benfica                    0.421488
# Paris Saint Germain        0.406504
# Atlético Madrid            0.397163
# Sevilla                    0.376923
# Porto                      0.375000
# FC Bayern München          0.357692
# Borussia Dortmund          0.337793
# Athletic Club de Bilbao    0.337662
# Name: peak_player, dtype: float64
# team_name
# Paraná                   0.750000
# Ceará Sporting Club      0.700000
# 12 de Octubre            0.533333
# Sport Club do Recife     0.524590
# América Mineiro          0.500000
# Cienciano                0.488889
# Qingdao Hainiu           0.475410
# América Futebol Clube    0.475000
# Altay                    0.468750
# Shanghai Shenhua         0.462121
# Name: falling_star, dtype: float64

# %% [markdown]
# # Advanced approach

# %% [markdown]
# ### Find the team rankings

# %%
def player_classifier(overall_score,mean, std):
    tvalue = stats.norm.cdf(overall_score, loc = mean, scale = std)
    threadshold_lt = {0.999:"world-top player", 0.99:"top player", 0.9:"great player", 
                      0.5:"above-average player", 0.1:"below-average player", 0:"bad player"}
    threadshold_key = sorted(threadshold_lt.keys())
    left = 0 
    right = len(threadshold_key) -1
    result = None
    # binary search
    while left <= right:
        mid = (left+right)//2
        if threadshold_key[mid] <= tvalue:
            result = threadshold_key[mid]
            left = mid + 1
        else:
            right = mid - 1
    
    return threadshold_lt[result]

stats_dict = male_players_df.groupby(['fifa_version'])['overall'].agg(['mean','std']).to_dict('index')

def map_player_classifier(row):
    mean = stats_dict[row['fifa_version']]['mean']
    std = stats_dict[row['fifa_version']]['std']
    return player_classifier(row['overall'], mean, std)

# %%
# Apply the player classifier
classified_player = merged_df.copy(deep=True)
classified_player['player_class'] = classified_player.apply(map_player_classifier, axis=1)

# Keep only the players that have played for at least two teams
classified_player = classified_player.groupby('player_id').filter(lambda x: x['team_id'].nunique() >= 2)

# Keep only the players that have been classified as at least two different classes
classified_player = classified_player.groupby('player_id').filter(lambda x: x['player_class'].nunique() >= 2)

# Show the classified players
display(classified_player.head())
# Out:
#    player_id  fifa_version     short_name  overall  age  team_id  \
# 1     231747            23      K. Mbappé       91   23       73
# 3     193041            23       K. Navas       88   35       73
# 5     230621            23  G. Donnarumma       88   23       73
# 7     155862            23   Sergio Ramos       84   36       73
# 8     235212            23      A. Hakimi       84   23       73
#
#              team_name                                    player_face_url  \
# 1  Paris Saint Germain  https://cdn.sofifa.net/players/231/747/23_120.png
# 3  Paris Saint Germain  https://cdn.sofifa.net/players/193/041/23_120.png
# 5  Paris Saint Germain  https://cdn.sofifa.net/players/230/621/23_120.png
# 7  Paris Saint Germain  https://cdn.sofifa.net/players/155/862/23_120.png
# 8  Paris Saint Germain  https://cdn.sofifa.net/players/235/212/23_120.png
#
#    rising_star  peak_player  falling_star      player_class
# 1         True        False         False  world-top player
# 3        False        False         False  world-top player
# 5         True        False         False  world-top player
# 7        False        False         False        top player
# 8         True        False         False        top player

# %%
# Calculate the number of players in each class
club_rising_stars_classified = merged_df[merged_df["rising_star"] == True].groupby('team_name')['rising_star'].value_counts().sort_values(ascending=False)
club_peak_players_classified = merged_df[merged_df["peak_player"] == True].groupby('team_name')['peak_player'].value_counts().sort_values(ascending=False)
club_falling_stars_classified = merged_df[merged_df["falling_star"] == True].groupby('team_name')['falling_star'].value_counts().sort_values(ascending=False)

# %%
# Show the rankings
display(club_rising_stars_classified.head(10))
display(club_peak_players_classified.head(10))
display(club_falling_stars_classified.head(10))
# Out:
# team_name            rising_star
# Ajax                 True           116
# PSV                  True            98
# Olympique Lyonnais   True            87
# Sporting CP          True            87
# Bayer 04 Leverkusen  True            86
# RB Leipzig           True            80
# FC Barcelona         True            77
# Arsenal              True            73
# Tottenham Hotspur    True            71
# Feyenoord            True            70
# Name: rising_star, dtype: int64
# team_name          peak_player
# Liverpool          True           121
# Napoli             True           116
# Chelsea            True           108
# Manchester United  True           108
# Tottenham Hotspur  True           106
# West Ham United    True           105
# Manchester City    True           103
# Arsenal            True           103
# Borussia Dortmund  True           101
# Everton            True           100
# Name: peak_player, dtype: int64
# team_name                 falling_star
# Deportivo Pasto           True            90
# River Plate               True            90
# Universidad Católica      True            88
# Antalyaspor               True            79
# Perth Glory               True            74
# Rosario Central           True            73
# Western Sydney Wanderers  True            72
# AIK                       True            71
# Real Salt Lake            True            70
# Newell's Old Boys         True            66
# Name: falling_star, dtype: int64

# %% [markdown]
# ### Find the top 3 most relevant players per team

# %%
# Get the team_ids 
rising_team_ids = club_rising_stars_classified.head(7).index.get_level_values('team_name').tolist()
peak_team_ids = club_peak_players_classified.head(7).index.get_level_values('team_name').tolist()
falling_team_ids = club_falling_stars_classified.head(7).index.get_level_values('team_name').tolist()

# Create an empty dataframe to store the results
rising_stars_df = pd.DataFrame()
peak_players_df = pd.DataFrame()
falling_stars_df = pd.DataFrame()

# Iterate over each team_id
for team_name in rising_team_ids:

    # Filter the merged_df for the current team_id and the category condition
    rising_stars = merged_df[(merged_df['team_name'] == team_name) & (merged_df['rising_star'] == True)]

    # Sort the players by overall in descending order
    rising_stars = rising_stars.sort_values('overall', ascending=False)

    # Drop duplicates
    rising_stars.drop_duplicates('player_id', keep='first', inplace=True)
    
    # Take the top 3 players
    rising_stars = rising_stars.head(3)
    
    # Update the dataframes
    rising_stars_df = pd.concat([rising_stars_df, rising_stars], ignore_index=True)

# Iterate over each team_id
for team_name in peak_team_ids:

    # Filter the merged_df for the current team_id and the category condition
    peak_players = merged_df[(merged_df['team_name'] == team_name) & (merged_df['peak_player'] == True)]

    # Sort the players by overall in descending order
    peak_players = peak_players.sort_values('overall', ascending=False)

    # Drop duplicates
    peak_players.drop_duplicates('player_id', keep='first', inplace=True)
    
    # Take the top 3 players
    peak_players = peak_players.head(3)
    
    # Update the dataframes
    peak_players_df = pd.concat([peak_players_df, peak_players], ignore_index=True)

# Iterate over each team_id
for team_name in falling_team_ids:

    # Filter the merged_df for the current team_id and the category condition
    falling_stars = merged_df[(merged_df['team_name'] == team_name) & (merged_df['falling_star'] == True)]

    # Sort the players by overall in descending order
    falling_stars = falling_stars.sort_values('overall', ascending=False)

    # Drop duplicates
    falling_stars.drop_duplicates('player_id', keep='first', inplace=True)
    
    # Take the top 3 players
    falling_stars = falling_stars.head(3)
    
    # Update the dataframes
    falling_stars_df = pd.concat([falling_stars_df, falling_stars], ignore_index=True)

# Keep only the relevant columns
columns = ["team_name", "short_name", "overall", "age", "fifa_version", "player_face_url"]
rising_stars_df = rising_stars_df.loc[:, columns]
peak_players_df = peak_players_df.loc[:, columns]
falling_stars_df = falling_stars_df.loc[:, columns]

# Change the fifa_version to the year
rising_stars_df['fifa_version'] = rising_stars_df['fifa_version'].apply(lambda x: "20" + str(x))
peak_players_df['fifa_version'] = peak_players_df['fifa_version'].apply(lambda x: "20" + str(x))
falling_stars_df['fifa_version'] = falling_stars_df['fifa_version'].apply(lambda x: "20" + str(x))

rising_stars_df = rising_stars_df.rename(columns={'fifa_version': 'year'})
peak_players_df = peak_players_df.rename(columns={'fifa_version': 'year'})
falling_stars_df = falling_stars_df.rename(columns={'fifa_version': 'year'})

# Show the results
print("Rising stars:")
display(rising_stars_df)

print("Peak players:")
display(peak_players_df)

print("Falling stars:")
display(falling_stars_df)
# Out:
# Rising stars:
#               team_name       short_name  overall  age  year  \
# 0                  Ajax       M. de Ligt       85   18  2019
# 1                  Ajax         A. Onana       85   23  2020
# 2                  Ajax       F. de Jong       84   21  2019
# 3                   PSV        H. Lozano       82   22  2019
# 4                   PSV      S. Bergwijn       81   20  2019
# 5                   PSV         C. Gakpo       81   22  2022
# 6    Olympique Lyonnais         N. Fekir       84   23  2018
# 7    Olympique Lyonnais     A. Lacazette       82   23  2015
# 8    Olympique Lyonnais       M. Dembélé       82   22  2020
# 9           Sporting CP  Bruno Fernandes       85   23  2019
# 10          Sporting CP   Gelson Martins       82   22  2018
# 11          Sporting CP      Pedro Porro       82   22  2023
# 12  Bayer 04 Leverkusen         M. Diaby       84   22  2023
# 13  Bayer 04 Leverkusen       K. Havertz       84   20  2020
# 14  Bayer 04 Leverkusen          B. Leno       83   23  2016
# 15           RB Leipzig        T. Werner       86   23  2020
# 16           RB Leipzig        C. Nkunku       86   23  2022
# 17           RB Leipzig         N. Keïta       83   22  2018
# 18         FC Barcelona           Neymar       90   23  2016
# 19         FC Barcelona       F. de Jong       86   23  2021
# 20         FC Barcelona            Pedri       85   19  2023
#
#                                       player_face_url
# 0   https://cdn.sofifa.net/players/235/243/19_120.png
# 1   https://cdn.sofifa.net/players/226/753/20_120.png
# 2   https://cdn.sofifa.net/players/228/702/19_120.png
# 3   https://cdn.sofifa.net/players/221/992/19_120.png
# 4   https://cdn.sofifa.net/players/225/953/19_120.png
# 5   https://cdn.sofifa.net/players/242/516/22_120.png
# 6   https://cdn.sofifa.net/players/216/594/18_120.png
# 7   https://cdn.sofifa.net/players/193/301/15_120.png
# 8   https://cdn.sofifa.net/players/211/591/20_120.png
# 9   https://cdn.sofifa.net/players/212/198/19_120.png
# 10  https://cdn.sofifa.net/players/227/055/18_120.png
# 11  https://cdn.sofifa.net/players/243/576/23_120.png
# 12  https://cdn.sofifa.net/players/241/852/23_120.png
# 13  https://cdn.sofifa.net/players/235/790/20_120.png
# 14  https://cdn.sofifa.net/players/192/563/16_120.png
# 15  https://cdn.sofifa.net/players/212/188/20_120.png
# 16  https://cdn.sofifa.net/players/232/411/22_120.png
# 17  https://cdn.sofifa.net/players/220/971/18_120.png
# 18  https://cdn.sofifa.net/players/190/871/16_120.png
# 19  https://cdn.sofifa.net/players/228/702/21_120.png
# 20  https://cdn.sofifa.net/players/251/854/23_120.png
# Peak players:
#             team_name       short_name  overall  age  year  \
# 0           Liverpool         M. Salah       91   29  2022
# 1           Liverpool      V. van Dijk       91   27  2020
# 2           Liverpool          S. Mané       90   27  2020
# 3              Napoli     K. Koulibaly       88   29  2021
# 4              Napoli       L. Insigne       87   26  2018
# 5              Napoli        M. Hamšík       87   29  2018
# 6             Chelsea        E. Hazard       91   26  2018
# 7             Chelsea         N. Kanté       89   28  2020
# 8             Chelsea      T. Courtois       89   25  2018
# 9   Manchester United           De Gea       91   26  2018
# 10  Manchester United         P. Pogba       88   24  2018
# 11  Manchester United       A. Sánchez       88   28  2018
# 12  Tottenham Hotspur          H. Kane       90   24  2019
# 13  Tottenham Hotspur           H. Son       89   28  2022
# 14  Tottenham Hotspur       C. Eriksen       88   25  2018
# 15    West Ham United  Felipe Anderson       84   25  2019
# 16    West Ham United         D. Payet       83   28  2016
# 17    West Ham United        S. Haller       82   25  2020
# 18    Manchester City     K. De Bruyne       91   27  2019
# 19    Manchester City          Ederson       89   27  2022
# 20    Manchester City        S. Agüero       89   29  2018
#
#                                       player_face_url
# 0   https://cdn.sofifa.net/players/209/331/22_120.png
# 1   https://cdn.sofifa.net/players/203/376/20_120.png
# 2   https://cdn.sofifa.net/players/208/722/20_120.png
# 3   https://cdn.sofifa.net/players/201/024/21_120.png
# 4   https://cdn.sofifa.net/players/198/219/18_120.png
# 5   https://cdn.sofifa.net/players/171/877/18_120.png
# 6   https://cdn.sofifa.net/players/183/277/18_120.png
# 7   https://cdn.sofifa.net/players/215/914/20_120.png
# 8   https://cdn.sofifa.net/players/192/119/18_120.png
# 9   https://cdn.sofifa.net/players/193/080/18_120.png
# 10  https://cdn.sofifa.net/players/195/864/18_120.png
# 11  https://cdn.sofifa.net/players/184/941/18_120.png
# 12  https://cdn.sofifa.net/players/202/126/19_120.png
# 13  https://cdn.sofifa.net/players/200/104/22_120.png
# 14  https://cdn.sofifa.net/players/190/460/18_120.png
# 15  https://cdn.sofifa.net/players/201/995/19_120.png
# 16  https://cdn.sofifa.net/players/177/388/16_120.png
# 17  https://cdn.sofifa.net/players/205/693/20_120.png
# 18  https://cdn.sofifa.net/players/192/985/19_120.png
# 19  https://cdn.sofifa.net/players/210/257/22_120.png
# 20  https://cdn.sofifa.net/players/153/079/18_120.png
# Falling stars:
#                    team_name     short_name  overall  age  year  \
# 0            Deportivo Pasto    M. Casierra       70   31  2018
# 1            Deportivo Pasto   E. Hernández       70   31  2018
# 2            Deportivo Pasto      J. Lopera       70   30  2018
# 3                River Plate  L. Pisculichi       75   32  2017
# 4                River Plate    R. Aliendro       75   31  2023
# 5                River Plate     J. Saviola       75   33  2016
# 6       Universidad Católica  J. Fuenzalida       75   31  2017
# 7       Universidad Católica    F. Zampedri       75   33  2022
# 8       Universidad Católica        L. Aued       75   31  2019
# 9                Antalyaspor   Luiz Adriano       75   35  2023
# 10               Antalyaspor        A. Poli       75   31  2022
# 11               Antalyaspor    L. Podolski       74   35  2021
# 12               Perth Glory   Diego Castro       75   34  2018
# 13               Perth Glory   B. Fornaroli       74   31  2020
# 14               Perth Glory   D. Sturridge       72   31  2022
# 15           Rosario Central       M. Ruben       75   34  2022
# 16           Rosario Central     M. Caruzzo       75   33  2019
# 17           Rosario Central      J. Pinola       75   33  2017
# 18  Western Sydney Wanderers      N. Müller       75   31  2020
# 19  Western Sydney Wanderers         Cejudo       74   33  2018
# 20  Western Sydney Wanderers   P. Schwegler       74   33  2021
#
#                                       player_face_url
# 0   https://cdn.sofifa.net/players/214/118/18_120.png
# 1   https://cdn.sofifa.net/players/221/463/18_120.png
# 2   https://cdn.sofifa.net/players/214/106/18_120.png
# 3   https://cdn.sofifa.net/players/158/969/17_120.png
# 4   https://cdn.sofifa.net/players/233/029/23_120.png
# 5   https://cdn.sofifa.net/players/001/803/16_120.png
# 6   https://cdn.sofifa.net/players/196/069/17_120.png
# 7   https://cdn.sofifa.net/players/232/670/22_120.png
# 8   https://cdn.sofifa.net/players/206/152/19_120.png
# 9   https://cdn.sofifa.net/players/180/826/23_120.png
# 10  https://cdn.sofifa.net/players/185/174/22_120.png
# 11  https://cdn.sofifa.net/players/150/516/21_120.png
# 12  https://cdn.sofifa.net/players/147/006/18_120.png
# 13  https://cdn.sofifa.net/players/189/225/20_120.png
# 14  https://cdn.sofifa.net/players/171/833/22_120.png
# 15  https://cdn.sofifa.net/players/165/560/22_120.png
# 16  https://cdn.sofifa.net/players/190/576/19_120.png
# 17  https://cdn.sofifa.net/players/146/963/17_120.png
# 18  https://cdn.sofifa.net/players/183/871/20_120.png
# 19  https://cdn.sofifa.net/players/146/377/18_120.png
# 20  https://cdn.sofifa.net/players/158/905/21_120.png

# %%
# Create the generated folder if it doesn't exist
import os
if not os.path.exists("../generated"):
    os.makedirs("../generated")

# Save the results as CSV
rising_stars_df.to_csv("../generated/rising_stars_players.csv", index=False)
peak_players_df.to_csv("../generated/peak_players_players.csv", index=False)
falling_stars_df.to_csv("../generated/falling_stars_players.csv", index=False)
